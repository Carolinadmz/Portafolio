# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolinadmz/Portafolio/blob/main/Ejercicios/AND2_MLP_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Cargar las librerías
import numpy as np #matrices
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential #construir capa por capa

# %%
#Cargar la base de datos OR2
training_data = np.array([[0,0],[0,1],[1,0],[1,1]],"float32")

# %%
training_data.shape
# Out:
# (4, 2)

# %%
# Cargar el conjunto de etiquetas deseadas (salidas)
target_data = np.array([[0],[0],[0],[1]],"float32")

# %%
target_data
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %%
# Crear una red para resolver el problema de la compuerta OR2
model = Sequential()
model.add(Dense(40, input_dim=2, activation='relu')) #input_dim, es el número de entradas y 16 salidas ocultas, el valor que quiera, imput_dim solo va en la primera capa
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilar el modelo
model.compile(loss='mean_squared_error',
              optimizer='sgd', #sgd  descenso de gradiente estocástico
              metrics=['binary_accuracy'])

# %%
# Entrenar el modelo
model.fit(training_data, target_data, epochs=800) #epochs son las iteraciones
# Out:
# Epoch 1/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - binary_accuracy: 0.7500 - loss: 0.2368
# Epoch 2/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - binary_accuracy: 0.7500 - loss: 0.2366
# Epoch 3/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - binary_accuracy: 0.7500 - loss: 0.2364
# Epoch 4/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - binary_accuracy: 0.7500 - loss: 0.2362
# Epoch 5/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.7500 - loss: 0.2359
# Epoch 6/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - binary_accuracy: 0.7500 - loss: 0.2357
# Epoch 7/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.7500 - loss: 0.2355
# Epoch 8/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - binary_accuracy: 0.7500 - loss: 0.2353
# Epoch 9/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - binary_accuracy: 0.7500 - loss: 0.2350
# Epoch 10/800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - binary_accuracy: 0.7500 - loss: 0.2348
# Epoch 11/800
# ...

# %%
# Mostrar las predicciones
print(model.predict(training_data).round())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[0.]
#  [0.]
#  [0.]
#  [1.]]
