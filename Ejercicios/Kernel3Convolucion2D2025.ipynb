# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolinadmz/Portafolio/blob/main/Ejercicios/Kernel3Convolucion2D2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='navy'>**Convolución 2D:** </font>
# <font color='blue'> Se deberá subir la ejecución de este cuaderno en el repositorio privado de cada alumno, dentro de la carpeta **PRÁCTICAS** y creando una subcarpeta con el nombre de CONVOLUCION2D, recuerde que deberán subirse todas las imágenes utilizadas en el reporte
# ## <font color='purple'>**Convolución 2D**</font>
#
# ![Convolucion](https://github.com/jambdeep/ApoyoMaterias/blob/main/IMAGES/convolucion2D.gif?raw=true)
#
# ![Operacion](https://github.com/jambdeep/ApoyoMaterias/blob/main/IMAGES/conv_orig.jpeg?raw=true)

# %%
from skimage import io, color, exposure # simbolo de convolución *, se le aplica un kernel que es un filtro, matrices cuadradas(3x3), (4x4)...
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img=io.imread('/content/drive/MyDrive/Colab Notebooks/2025-IA/perfil.jpg')

# %%
img.shape # el 3 significa que esta en formato RGB, 3 canales: rojo, verde y azul
# Out:
# (364, 248, 3)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img=color.rgb2gray(img)# convertir la imagen de color a grises

# %%
plt.imshow(img, cmap=plt.cm.gray) # como ya no esta en color, se debe agregar el mapa de color
plt.axis('off')
plt.show()

# %%
img.shape # ahora solo tiene una matriz
# Out:
# (364, 248)

# %%
def convolved2d(image, kernel):
  kernel = np.flipud(np.fliplr(kernel))
  output = np.zeros_like(image)
  image_padded = np.zeros((image.shape[0] + 2, image.shape[1]+2))
  image_padded[1:-1, 1:-1] = image
  for x in range(image.shape[1]):
    for y in range(image.shape[0]):
      output[y,x]=(kernel*image_padded[y:y+3,x:x+3]).sum()
  return output

# %%
kernel = np.array( [ [0.0625,0.125,0.0625], [0.125,0.25,0.125], [0.0625,0.125,0.0625
] ] )
image_filt = convolved2d(img, kernel)

# %%
plt.imshow(image_filt, cmap=plt.cm.gray) # se usa un filtro para resaltar algo
plt.axis('off')
plt.show()

# %%
image_filt_equalized = exposure.equalize_adapthist(image_filt/np.max(np.abs(image_filt)), clip_limit=0.03)
plt.imshow(image_filt_equalized, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %% [markdown]
# ### <font color='orange'>***Ejercicio en clase***</font>
#
# ### <font color='blue'>**Repetir el cuaderno realizando 3 convoluciones a la misma imagen empleando diferentes kernel a los vistos en clase, para ello puede emplear el enlace adjunto**
#
# [Kernel's](https://setosa.io/ev/image-kernels/)
